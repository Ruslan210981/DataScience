# %%
#Домашнее задание №3 - Функции одной переменной
#Задание 1.

#Вычислить значения первой и второй производной функции:
from sympy import *
import numpy as np
x = Symbol('x')
f1 = (x**5 + 4*sin(2*x)+cos(3*x + 3)).diff(x)
print("Значение первой производной в точке х = 1, равно: ",f1.subs(x,1.0))

f2 = f1.diff(x)
print("Значение второй производной в точке х = 1, равно: ",f2.subs(x,1.0))

#в точке x = 1.
# Out:
# Значение первой производной в точке х = 1, равно:  2.50907180221964
# Значение второй производной в точке х = 1, равно:  -3.19029140906420

# %%
# Постройте график функции, первой и второй производной на отрезке -5, 5.
import matplotlib.pyplot as plt
f = sin(2*x+1)**5
n = np.arange(-5,5,0.1)
f1 = lambdify(x, f) 
f2 = lambdify(x, f.diff(x)) 
y1 = f1(n)
y1
y2 = f2(n)
y2
plt.plot(n,y1)
plt.xlabel('n')
plt.ylabel('y1')

plt.plot(n,y2)
plt.xlabel('n')
plt.ylabel('y2')
plt.show()

# %%
def relu(x):
    return np.maximum(0.0, x)
x = np.arange(-3, 3, 0.1)
y = relu(x)

plt.plot(x, y)
plt.xlabel('x')
plt.ylabel('y')
plt.title('ReLU Function')
plt.show()

# %%
def relu_derivative(x):
    # Вычислить производную функции ReLU
    # Ваш код напишите ниже и результат передайте в переменную derivative
    
    derivative = 1*(x > 0);
    
    return derivative

# %%
def sigmoid(x):
    return 1 / (1 + np.exp(-x))
x = np.arange(-5, 5, 0.1)
y = sigmoid(x)

plt.plot(x, y)
plt.xlabel('x')
plt.ylabel('y')
plt.title('Sigmoid Function')
plt.show()

# %%
def sigmoid_derivative(x):
    # Вычислить производную сигмоидной функции
    # Ваш код напишите ниже и результат передайте в переменную derivative
    derivative = sigmoid(x)*(1-sigmoid(x))
    return derivative
sigmoid_derivative(0)
# Out:
# 0.25
